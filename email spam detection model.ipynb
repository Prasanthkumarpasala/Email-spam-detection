# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
url = "https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv"
df = pd.read_csv(url, sep='\t', names=['label', 'message'])

df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# Split dataset
X_train_raw, X_test_raw, y_train, y_test = train_test_split(df['message'], df['label'], test_size=0.2, random_state=42)

# TF-IDF vectorization with anti-overfitting settings
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.9, min_df=5)
X_train = vectorizer.fit_transform(X_train_raw)
X_test = vectorizer.transform(X_test_raw)

# %%
model = LogisticRegression(C=0.5, max_iter=10000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.5, max_iter=10000)

# %%
y_pred = model.predict(X_test)

acc = accuracy_score(y_test, y_pred)
print(f"Logistic Regression Accuracy: {acc:.4f}\n")
print(classification_report(y_test, y_pred))
# Out:
# Logistic Regression Accuracy: 0.9561
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       966
#            1       1.00      0.67      0.80       149
#
#     accuracy                           0.96      1115
#    macro avg       0.98      0.84      0.89      1115
# weighted avg       0.96      0.96      0.95      1115

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\rithv\anaconda3\lib\site-packages (3.1.1)
# Requirement already satisfied: mlflow-skinny==3.1.1 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (3.1.1)
# Requirement already satisfied: Flask<4 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (1.16.2)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: matplotlib<4 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (2.1.3)
# Requirement already satisfied: pandas<3 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (19.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (2.0.39)
# Requirement already satisfied: waitress<4 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (0.57.0)
# Requirement already satisfied: fastapi<1 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (0.115.14)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (1.34.1)
# Requirement already satisfied: packaging<26 in c:\users\rithv\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.1.1->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (5.29.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (2.10.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (4.12.2)
# Requirement already satisfied: uvicorn<1 in c:\users\rithv\anaconda3\lib\site-packages (from mlflow-skinny==3.1.1->mlflow) (0.35.0)
# Requirement already satisfied: Mako in c:\users\rithv\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.2.3)
# Requirement already satisfied: colorama in c:\users\rithv\appdata\roaming\python\python313\site-packages (from click<9,>=7.0->mlflow-skinny==3.1.1->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\rithv\anaconda3\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.1->mlflow) (2.40.3)
# Requirement already satisfied: pywin32>=304 in c:\users\rithv\appdata\roaming\python\python313\site-packages (from docker<8,>=4.0.0->mlflow) (310)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\rithv\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\rithv\anaconda3\lib\site-packages (from fastapi<1->mlflow-skinny==3.1.1->mlflow) (0.46.2)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\rithv\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\rithv\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\rithv\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\rithv\anaconda3\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\rithv\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.1.1->mlflow) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\rithv\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.1.1->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rithv\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.1->mlflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rithv\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.1->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\rithv\anaconda3\lib\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\rithv\anaconda3\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\rithv\appdata\roaming\python\python313\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\rithv\anaconda3\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.1->mlflow) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rithv\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rithv\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rithv\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rithv\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\rithv\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rithv\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.2.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\rithv\anaconda3\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.1.1->mlflow) (0.55b1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rithv\anaconda3\lib\site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rithv\anaconda3\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\rithv\anaconda3\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.1->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\rithv\anaconda3\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.1->mlflow) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\rithv\appdata\roaming\python\python313\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rithv\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.1->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rithv\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.1->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rithv\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.1->mlflow) (2025.6.15)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\rithv\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.1->mlflow) (0.4.8)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rithv\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rithv\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rithv\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\rithv\anaconda3\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.1->mlflow) (4.7.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rithv\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.1->mlflow) (1.3.0)
# Requirement already satisfied: h11>=0.8 in c:\users\rithv\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.1.1->mlflow) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rithv\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask<4->mlflow) (3.0.2)

# %%
import mlflow
import mlflow.sklearn
import joblib

# %%
import os

# Create 'models' directory if it doesn't exist
os.makedirs("models", exist_ok=True)

# %%
mlflow.sklearn.autolog()
with mlflow.start_run():
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)

    mlflow.log_metric("accuracy", acc)
    joblib.dump(model, "models/logistic_spam_model.joblib")
    joblib.dump(vectorizer, "models/tfidf_vectorizer.joblib")

    print(f"Accuracy: {acc:.4f}")
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# 2025/07/06 16:03:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Accuracy: 0.9561
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       966
#            1       1.00      0.67      0.80       149
#
#     accuracy                           0.96      1115
#    macro avg       0.98      0.84      0.89      1115
# weighted avg       0.96      0.96      0.95      1115
